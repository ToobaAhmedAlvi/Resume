# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('CVdataset.csv',encoding ='ISO-8859-1')#importing data

# %%
data.head(10)
# Out:
#                         Category  \
# 0             project management
# 1                 data analytics
# 2  senior application consultant
# 3             project management
# 4                 data analytics
# 5             project management
# 6             project management
# 7                 data analytics
# 8                 JAVA developer
# 9                   Supply chain
#
#                                              Resumes  Unnamed: 2  Unnamed: 3  \
# 0  contact wwwlinkedincominelbiemoongalinkedingit...         NaN         NaN
# 1   tooba ahmed alvi jr software developer    p  ...         NaN         NaN
# 2   samama hill view block  gulistanejauhar karac...         NaN         NaN
# 3  contact karachi pakistan email danishaligmailc...         NaN         NaN
# 4  farzana kazi c bokhari commercial lane  phase ...         NaN         NaN
# 5    Seeking a challenging and research based car...         NaN         NaN
# ...

# %%
data.dropna(how='any',axis=1,inplace=True)

# %%
data
# Out:
#                           Category  \
# 0               project management
# 1                   data analytics
# 2    senior application consultant
# 3               project management
# 4                   data analytics
# ..                             ...
# 105                 data analytics
# 106                 data analytics
# 107          Operations Management
# 108                 data analytics
# 109  senior application consultant
#
#                                                Resumes
# 0    contact wwwlinkedincominelbiemoongalinkedingit...
# 1     tooba ahmed alvi jr software developer    p  ...
# 2     samama hill view block  gulistanejauhar karac...
# 3    contact karachi pakistan email danishaligmailc...
# 4    farzana kazi c bokhari commercial lane  phase ...
# ..                                                 ...
# 105  Andheri West,Maharashtra, Mumbai 400 018,INDIA...
# 106  contact home noumansiddiquigmailcom wwwlinkedi...
# ...

# %%
data.shape
# Out:
# (110, 2)

# %%
data.columns
# Out:
# Index(['Category', 'Resumes'], dtype='object')

# %%
data.dtypes
# Out:
# Category    object
# Resumes     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  110 non-null    object
#  1   Resumes   110 non-null    object
# dtypes: object(2)
# memory usage: 1.8+ KB

# %%
data.isnull().sum #data.isna().sum
# Out:
# <bound method DataFrame.sum of      Category  Resumes
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4       False    False
# ..        ...      ...
# 105     False    False
# 106     False    False
# 107     False    False
# 108     False    False
# 109     False    False
#
# [110 rows x 2 columns]>

# %%
# Out:
# <bound method DataFrame.sum of      Category  Resumes
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4       False    False
# ..        ...      ...
# 105     False    False
# 106     False    False
# 107     False    False
# 108     False    False
# 109     False    False
#
# [110 rows x 2 columns]>

# %%
data.describe()
# Out:
#               Category                                            Resumes
# count              110                                                110
# unique               7                                                104
# top     data analytics  contactdanishhussaingmailcomwwwlinkedincominda...
# freq                25                                                  3
